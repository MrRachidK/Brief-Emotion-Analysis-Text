# %% [markdown]
# ## Importation des librairies dont on a besoin

# %%
import os
import sys
from pathlib import Path
sys.path.insert(0, '/home/apprenant/Documents/Brief-Emotion-Analysis-Text/')
sys.path.append(Path(os.path.join(os.path.abspath(''), '../')).resolve().as_posix())
import pandas as pd
import spacy as sp
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from src.dataset import Dataset

# %% [markdown]
# ## Premier jeu de données

# %%
dataset_path = Path('/home/apprenant/Documents/Brief-Emotion-Analysis-Text/data/02_cleaned/cleaned_emotion_final.csv').resolve()
dataset = Dataset(dataset_path)
dataset.load()
dataset.preprocess_texts()
# Out:
# /home/apprenant/Documents/Brief-Emotion-Analysis-Text/src/utils.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   texts = texts.str.replace(r"(http|@)\S+", "")
# /home/apprenant/Documents/Brief-Emotion-Analysis-Text/src/utils.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   texts = texts.str.replace(r"[^a-z\':_]", " ")
# /home/apprenant/Documents/Brief-Emotion-Analysis-Text/src/utils.py:23: FutureWarning: The default value of regex will change from True to False in a future version.
#   texts = texts.str.replace(r"(can't|cannot)", 'can not')
# Time to clean up: 10.62 sec

# %%
dataset.cleaned_data.head()
# Out:
#      label                                               text
# 0  sadness                              didnt feel humiliated
# 1  sadness  go feeling hopeless damned hopeful around some...
# 2    anger          im grabbing minute post feel greedy wrong
# 3     love  ever feeling nostalgic fireplace know still pr...
# 4    anger                                    feeling grouchy

# %%
cleaned_dataset = dataset.cleaned_data

# %% [markdown]
# ### Tokenisation

# %%
cleaned_dataset_list = cleaned_dataset['text'].to_list()

tokenizer_w = WhitespaceTokenizer()
token_list = []
for i in cleaned_dataset_list:
    tokenized_list = tokenizer_w.tokenize(i) 
    token_list.append(tokenized_list)

# %%
# new_token_list = []
# for list in token_list:
#     for i in list:
#         new_token_list.append(i)

# %% [markdown]
# ### Stemming

# %%
def stemmer_snowball(text_list):
    snowball = SnowballStemmer(language='english')
    stemmed_list = []
    for liste in text_list:
        stemmed_sentence = []
        for i in liste:
            i = snowball.stem(i)
            stemmed_sentence.append(i)
        stemmed_list.append(stemmed_sentence)
    return stemmed_list

new_list = stemmer_snowball(token_list)
new_list
# Out:
# ',
#   'feel',
#   'thrill',
#   'firstborn'],
#  ['feel',
#   'like',
#   'tri',
#   'stay',
#   'faith',
#   'possibl',
#   'perceiv',
#   'real',
#   'event',
#   'happen',
#   'mountain'],
#  ['walia', 'feel', 'suspici', 'tarun', 'bani'],
#  ['not', 'feel', 'like', 'hostil', 'toward', 'other', 'fail', 'nice'],
#  ['feel', 'glad', 'littl', 'blog', 'share', 'danger', 'see', 'path', 'ahead'],
#  ['wake', 'feel', 'cranki', 'sort'],
#  ['say', 'feel', 'like', 'im', 'tortur'],
#  ['cant',
#   'help',
#   'look',
#   'back',
#   'child',
#   'feel',
#   'rather',
#   'jealous',
#   'also',
#   'delight',
#   'live',
#   'time',
#   'nine',
#   'year',
#   'old',
#   'child',
#   'part',
#   'world',
#   'read',
#   'thousand',
#   'book',
#   'year',
#   'wish',
#   'abl'],
#  ['im', 'feel', 'bit', 'cranki', 'today'],
#  ['even',
#   'dare',
#   'say',
#   'biggest',
#   'stiller',
#   'vaughn',
#   'hater',
#   'still',
#   'could',
#   'get',
#   'enjoy',
#   'movi',
#   'not',
#   'feel',
#   'annoy',
#   'perform',
#   'charact'],
#  ['make',
#   'punjabi',
#   'lobia',
#   'masala',
#   'most',
#   'winter',
#   'feel',
#   'protein',
#   'punch',
#   'spice',
#   'rich',
#   'recip',
#   'winter',
#   'warmer',
#   'one'],
#  ['truli', 'terrifi', 'still', 'feel', 'shaken', 'uneasi'],
#  ['begin', 'feel', 'burden', 'thing', 'amp', 'long', 'empti'],
#  ['write',
#   'space',
#   'feel',
#   'quit',
#   'nostalg',
#   'mind',
#   'race',
#   'back',
#   'good',
#   'old',
#   'day',
#   'use',
#   'daili',
#   'park',
#   'learn',
#   'memori'],
#  ['feel', 'numb', 'f'],
#  ['sit', 'tonight', 'pensiv', 'tens', 'feel', 'littl', 'fear'],
#  ['want',
#   'someon',
#   'know',
#   'know',
#   'thought',
#   'feel',
#   'want',
#   'keep',
#   'loyal',
#   'faith',
#   'reader'],
#  ['feel', 'joy', 'anticip', 'divin', 'right'],
#  ['feel',
#   'overwhelm',
#   'ask',
#   'bqff',
#   'keep',
#   'hous',
#   'theyr',
#   'readi',
#   'load',
#   'dont',
#   'feel',
#   'behind'],
#  ['feel',
#   'thrill',
#   'abl',
#   'investig',
#   'person',
#   'mytholog',
#   'around',
#   'subject'],
#  ['feel', 'creativ', 'right', 'make', 'happi'],
#  ['could',
#   'wear',
#   'casual',
#   'shop',
#   'trip',
#   'feel',
#   'fabul',
#   'without',
#   'even',
#   'tri'],
#  ['want',
#   'other',
#   'happi',
#   'mean',
#   'step',
#   'back',
#   'yet',
#   'feel',
#   'like',
#   'allow',
#   'happi',
#   'deserv',
#   'even',
#   'deserv'],
#  ['limit',
#   'reason',
#   'without',
#   'caus',
#   'greater',
#   'injuri',
#   'sort',
#   'physic',
#   'exercis',
#   'start',
#   'feel',
#   'horribl'],
#  ['would', 'alway', 'feel', 'amaz', 'impact', 'year', 'old', 'subject'],
#  ['feel', 'lucki', 'live', 'portland', 'land', 'delici', 'food'],
#  ['feel',
#   'pretti',
#   'cranki',
#   'morn',
#   'stop',
#   'realli',
#   'made',
#   'feel',
#   'lot',
#   'better'],
#  ['didnt', 'feel', 'cold', 'fire', 'everi', 'night'],
#  ['im',
#   'also',
#   'feel',
#   'cranki',
#   'main',
#   'charact',
#   'scientist',
#   'brother',
#   'observ',
#   'moon',
#   'mention',
#   'zero',
#   'graviti'],
#  ['folk', 'im', 'feel', 'sociabl'],
#  ['feel',
#   'divin',
#   'forc',
#   'strong',
#   'sometim',
#   'wonder',
#   'agnost',
#   'atheist',
#   'judeo',
#   'christian',
#   'fundamentalist',
#   'feel',
#   'excit',
#   'heart'],
#  ['start', 'feel', 'discourag', 'thought', 'one', 'day'],
#  ['feel',
#   'like',
#   'mayb',
#   'go',
#   'stop',
#   'love',
#   'mayb',
#   'true',
#   'im',
#   'terribl',
#   'wife'],
#  ['im',
#   'alreadi',
#   'feel',
#   'sentiment',
#   'time',
#   'newborn',
#   'wee',
#   'sad',
#   'outgrown',
#   'fave',
#   'thrift',
#   'outfit'],
#  ['feel', 'like', 'ive', 'innoc', 'version', 'one', 'night', 'stand'],
#  ['finish',
#   'type',
#   'post',
#   'realis',
#   'ok',
#   'no',
#   'longer',
#   'feel',
#   'annoy',
#   'angri',
#   'even',
#   'sad'],
#  ['refus',
#   'rate',
#   'book',
#   'publish',
#   'feel',
#   'snobbish',
#   'take',
#   'say',
#   'jeanett',
#   'winterson',
#   'not',
#   'write',
#   'essenti',
#   'not',
#   'wish',
#   'anyth',
#   'scope',
#   'explor'],
#  ['feel',
#   'petti',
#   'even',
#   'though',
#   'thought',
#   'arent',
#   'real',
#   'flesh',
#   'thought',
#   'flutter',
#   'feel',
#   'like',
#   'kind',
#   'thought'],
#  ['felt', 'sad', 'apprehens', 'angri', 'vertigo', 'left', 'feel', 'uncertain'],
#  ['feel', 'like', 'ive', 'got', 'handl', 'trust', 'instinct'],
#  ['feel', 'complac', 'start', 'think', 'smart'],
#  ['admit',
#   'defeat',
#   'ask',
#   'half',
#   'come',
#   'back',
#   'lake',
#   'coz',
#   'feel',
#   'uptight',
#   'alreadi'],
#  ['feel', 'journalist', 'blame'],
#  ['miss',
#   'month',
#   'combin',
#   'class',
#   'pretti',
#   'much',
#   'bed',
#   'ridden',
#   'month',
#   'semest',
#   'feel',
#   'realli',
#   'amaz',
#   'abl',
#   'pass'],
#  ['put', 'leg', 'around', 'wrap', 'arm', 'feel', 'safe'],
#  ['feel', 'loyal', 'luci'],
#  ['feel',
#   'like',
#   'im',
#   'not',
#   'pretti',
#   'enough',
#   'like',
#   'person',
#   'bore',
#   'obnoxi'],
#  ['reliev', 'excit', 'feel', 'confid'],
#  ['im',
#   'proud',
#   'craft',
#   'someth',
#   'peopl',
#   'care',
#   'even',
#   'enough',
#   'click',
#   'make',
#   'feel',
#   'wonder'],
#  ['switch',
#   'song',
#   'one',
#   'begin',
#   'make',
#   'feel',
#   'littl',
#   'melancholi',
#   'fuck',
#   'need'],
#  ['feel',
#   'embarrass',
#   'talk',
#   'time',
#   'feel',
#   'small',
#   'moment',
#   'like',
#   'favor',
#   'not',
#   'deserv',
#   'given',
#   'attent'],
#  ['sound',
#   'entitl',
#   'cant',
#   'help',
#   'feel',
#   'disappoint',
#   'even',
#   'though',
#   'alreadi',
#   'knew',
#   'go'],
#  ['rememb',
#   'feel',
#   'husband',
#   'felt',
#   'would',
#   'see',
#   'peopl',
#   'rude',
#   'mom',
#   'mom',
#   'sweet',
#   'self'],
#  ['feel', 'clever'],
#  ['feel', 'remors', 'breakfast', 'took', 'diet', 'pill'],
#  ['feel',
#   'though',
#   'concept',
#   'lifestyl',
#   'chang',
#   'rather',
#   'weight',
#   'loss',
#   'beaten',
#   'death',
#   'realli',
#   'someth',
#   'believ',
#   'current',
#   'experienc'],
#  ['not', 'know', 'next', 'step', 'no', 'longer', 'feel', 'lost'],
#  ['feel', 'aw'],
#  ['believ',
#   'imagin',
#   'would',
#   'like',
#   'act',
#   'live',
#   'front',
#   'audienc',
#   'make',
#   'feel',
#   'joy'],
#  ['thought',
#   'mayb',
#   'hand',
#   'feel',
#   'funni',
#   'touch',
#   'hair',
#   'total',
#   'clean',
#   'forearm',
#   'becam',
#   'sticki'],
#  ['hate',
#   'moment',
#   'complet',
#   'feel',
#   'perfect',
#   'peopl',
#   'around',
#   'love',
#   'sudden',
#   'disappear'],
#  ['rememb',
#   'feel',
#   'littl',
#   'jealous',
#   'realiz',
#   'time',
#   'togeth',
#   'wasnt',
#   'sole',
#   'larger',
#   'network',
#   'social',
#   'interact',
#   'readi',
#   'progress',
#   'got'],
#  ['im',
#   'known',
#   'feel',
#   'affection',
#   'toward',
#   'ador',
#   'leonard',
#   'cohen',
#   'make',
#   'like',
#   'quit',
#   'lot'],
#  ['feel', 'realli', 'tranquil', 'right'],
#  ['feel', 'impati', 'yet', 'not', 'fulli', 'sure', 'search'],
#  ['tear', 'feel', 'unlov', 'even', 'though', 'know'],
#  ['feel',
#   'like',
#   'everyth',
#   'ive',
#   'noth',
#   'sincer',
#   'bother',
#   'want',
#   'hurt',
#   'even',
#   'told'],
#  ['feel',
#   'like',
#   'much',
#   'write',
#   'got',
#   'distract',
#   'home',
#   'wednesday',
#   'even',
#   'challeng',
#   'therefor',
#   'lost',
#   'train',
#   'thought'],
#  ['start', 'feel', 'littl', 'stress'],
#  ['admit', 'feel', 'bit', 'intimid', 'challeng'],
#  ['think',
#   'feel',
#   'vulner',
#   'due',
#   'stress',
#   'buy',
#   'new',
#   'sew',
#   'machin',
#   'printer'],
#  ['feel', 'asham', 'not', 'read', 'yet'],
#  ['hear',
#   'teenag',
#   'girl',
#   'devast',
#   'pimpl',
#   'face',
#   'morn',
#   'prom',
#   'feel',
#   'devast'],
#  ['woke', 'beauti', 'sunday', 'morn', 'feel', 'restless', 'miser'],
#  ['feel',
#   'unwelcom',
#   'work',
#   'sometim',
#   'think',
#   'peopl',
#   'might',
#   'talk',
#   'rel',
#   'bookmark',
#   'feel',
#   'unwelcom',
#   'work',
#   'sometim',
#   'think',
#   'peopl',
#   'might',
#   'talk',
#   'april',
#   'class',
#   'url',
#   'fn',
#   'n',
#   'href',
#   'http',
#   'w'],
#  ['dont',
#   'need',
#   'wear',
#   'mask',
#   'moment',
#   'show',
#   'feel',
#   'belov',
#   'without',
#   'missgiv'],
#  ['turn', 'head', 'away', 'even', 'feel', 'frighten'],
#  ['feel',
#   'like',
#   'go',
#   'supermarket',
#   'buy',
#   'someth',
#   'total',
#   'delici',
#   'dinner',
#   'money',
#   'mother',
#   'put',
#   'account',
#   'today'],
#  ['feel',
#   'fine',
#   'e',
#   'terminando',
#   'com',
#   'eight',
#   'day',
#   'week',
#   'um',
#   'ano',
#   'depoi'],
#  ['feel', 'uncertain', 'project'],
#  ['feel', 'vital', 'full', 'energi', 'everi', 'day', 'super', 'posit'],
#  ['feel',
#   'complet',
#   'dissatisfi',
#   'whole',
#   'world',
#   'human',
#   'charact',
#   'inconsist'],
#  ['mean', 'would', 'feel', 'euan', 'got', 'haul', 'murder', 'knew', 'innoc'],
#  ['experi',
#   'lot',
#   'experi',
#   'mention',
#   'sad',
#   'made',
#   'realiz',
#   'women',
#   'feel',
#   'career',
#   'path',
#   'somehow',
#   'go',
#   'determin',
#   'partner',
#   'support',
#   'not',
#   'children',
#   'ther',
#   'co',
#   'worker',
#   'etc'],
#  ['knew',
#   'high',
#   'school',
#   'pretti',
#   'fuckin',
#   'chill',
#   'say',
#   'girl',
#   'feel',
#   'insult',
#   'threaten',
#   'blog',
#   'wrote',
#   'would',
#   'like',
#   'apolog',
#   'offend',
#   'sorri'],
#  ['feel', 'talent', 'impact', 'thing', 'end', 'moment'],
#  ['find', 'feel', 'happi', 'feel', 'good'],
#  ['feel',
#   'bit',
#   'nostalg',
#   'wonder',
#   'passion',
#   'write',
#   'blog',
#   'time',
#   'week',
#   'gone'],
#  ['im', 'feel', 'particular', 'danger', 'chocol', 'cooki'],
#  ['im', 'feel', 'ok', 'alway', 'hand', 'sit', 'close'],
#  ['im',
#   'feel',
#   'quit',
#   'mellow',
#   'spite',
#   'rage',
#   'pms',
#   'past',
#   'day',
#   'mean',
#   'im',
#   'like',
#   'erupt',
#   'littl',
#   'no',
#   'warn'],
#  ['feel', 'like', 'innoc', 'victim', 'feel', 'win'],
#  ['actual',
#   'thought',
#   'would',
#   'feel',
#   'bother',
#   'sinc',
#   'ehb',
#   'woman',
#   'ow',
#   'spent',
#   'quit',
#   'bit',
#   'time',
#   'togeth',
#   'didnt',
#   'feel',
#   'much',
#   'anyth'],
#  ['feel', 'sincer', 'want', 'resolv', 'grievanc'],
#  ['also',
#   'attir',
#   'regular',
#   'moistur',
#   'oil',
#   'base',
#   'primer',
#   'yet',
#   'point',
#   'along',
#   'skin',
#   'color',
#   'feel',
#   'look',
#   'tender',
#   'great',
#   'time',
#   'day',
#   'someth',
#   'that',
#   'normal',
#   'not',
#   'attain'],
#  ['feel', 'apprehens', 'ride', 'ahead'],
#  ['feel', 'bother'],
#  ['feel', 'hint', 'belov', 'art', 'nouveau', 'era', 'bracelet'],
#  ['most',
#   'take',
#   'stair',
#   'occasion',
#   'feel',
#   'particular',
#   'letharg',
#   'number',
#   'consecut',
#   'late',
#   'night',
#   'bow',
#   'eas',
#   'conveni'],
#  ['not', 'feel', 'insecur', 'unsaf'],
#  ['feel',
#   'sort',
#   'pathet',
#   'say',
#   'iphon',
#   'internet',
#   'tv',
#   'must',
#   'have',
#   'let',
#   'honest'],
#  ['guess', 'understand', 'concern', 'help', 'feel', 'littl', 'reject'],
#  ['lace', 'shoe', 'pound', 'feel', 'hot', 'black', 'pavement'],
#  ['male',
#   'stupid',
#   'first',
#   'woman',
#   'cri',
#   'babi',
#   'get',
#   'feel',
#   'realli',
#   'cool',
#   'put',
#   'stupid',
#   'men',
#   'place'],
#  ['think',
#   'favorit',
#   'activ',
#   'child',
#   'often',
#   'tell',
#   'someon',
#   'feel',
#   'littl',
#   'unsur',
#   'life',
#   'direct',
#   'go',
#   'back',
#   'childhood',
#   'favorit',
#   'past',
#   'time',
#   'hold',
#   'mani',
#   'rich',
#   'clue'],
#  ['took',
#   'son',
#   'join',
#   'elihu',
#   'christmastim',
#   'insid',
#   'fine',
#   'home',
#   'love',
#   'mill',
#   'work',
#   'dark',
#   'lit',
#   'larg',
#   'state',
#   'christma',
#   'tree',
#   'live',
#   'room',
#   'feel',
#   'gentl',
#   'one',
#   'long',
#   'lost',
#   'friend',
#   'meet',
#   'first',
#   'time',
#   'adult',
#   'peopl'],
#  ['pray', 'everyday', 'feel', 'convinc', 'god', 'call', 'see'],
#  ['love', 'everyth', 'learn', 'feel', 'realli', 'passion', 'design'],
#  ['feel', 'brain', 'damag', 'get', 'worst', 'dis', 'moment'],
#  ['im',
#   'not',
#   'feel',
#   'terribl',
#   'adventur',
#   'plus',
#   'famili',
#   'visit',
#   'cant',
#   'complet',
#   'neglect',
#   'mean',
#   'go',
#   'busi',
#   'usual'],
#  ['funer', 'friend', 'kill', 'car', 'accid', 'age'],
#  ['feel', 'fear', 'near'],
#  ['wonder', 'feel', 'ecstat'],
#  ['peopl',
#   'realli',
#   'dont',
#   'mani',
#   'proplem',
#   'talk',
#   'feel',
#   'said',
#   'love',
#   'bitch',
#   'last',
#   'month',
#   'vain'],
#  ['think',
#   'write',
#   'realli',
#   'express',
#   'intens',
#   'emot',
#   'one',
#   'would',
#   'feel',
#   'lose',
#   'belov',
#   'spous'],
#  ['cant',
#   'imagin',
#   'agoni',
#   'folk',
#   'feel',
#   'wait',
#   'news',
#   'sentiment',
#   'thing'],
#  ['feel', 'make', 'even', 'care'],
#  ['feel', 'messi'],
#  ['feel', 'letharg', 'uninspir', 'next', 'morn', 'go'],
#  ['feel', 'insult'],
#  ['feel', 'need', 'littl', 'romant', 'boost', 'relationship'],
#  ['close',
#   'friend',
#   'intim',
#   'bodili',
#   'relationship',
#   'girlfriend',
#   'start',
#   'avoid',
#   'didnt',
#   'want',
#   'talk'],
#  ['use', 'elev', 'lexicon', 'feel', 'intellig'],
#  ['feel', 'wrong', 'world'],
#  ['feel',
#   'letharg',
#   'lazi',
#   'complet',
#   'uncompos',
#   'not',
#   'dress',
#   'someth',
#   'like'],
#  ['feel',
#   'director',
#   'editor',
#   'miss',
#   'teachabl',
#   'moment',
#   'tiphani',
#   'make',
#   'comment',
#   'nice',
#   'feel',
#   'like',
#   'everyon',
#   'els'],
#  ['write', 'anyth', 'feel', 'passion', 'least', 'genuin', 'interest'],
#  ['work',
#   'hard',
#   'shake',
#   'feel',
#   'popular',
#   'genr',
#   'novel',
#   'non',
#   'literari',
#   'fiction',
#   'not',
#   'make',
#   'book',
#   'less',
#   'legitim',
#   'less',
#   'someth',
#   'read',
#   'enjoy',
#   'analyz'],
#  ['feel', 'agit', 'empti', 'miss', 'someth'],
#  ['realiz', 'ignor', 'no', 'better', 'heartbreak', 'feel', 'helpless'],
#  ['still', 'feel', 'littl', 'daze', 'high', 'alarm', 'sinc', 'hour'],
#  ['would', 'feel', 'joy'],
#  ['feel', 'like', 'feed', 'food', 'touch', 'love', 'care', 'compass'],
#  ['feel', 'terribl', 'ignor', 'sweet', 'email'],
#  ['feel', 'deepli', 'offend', 'big', 'hurt', 'feel', 'fact'],
#  ['not', 'feel', 'overwhelm', 'nor', 'rush'],
#  ['feel', 'romant', 'final', 'finish', 'blog', 'post'],
#  ['kinda', 'steal', 'joshua', 'custom', 'feel', 'amus'],
#  ['feel', 'thrill', 'presenc', 'eye', 'feel', 'belief', 'peac', 'sincer'],
#  ['dontknow',
#   'never',
#   'feel',
#   'way',
#   'anyon',
#   'els',
#   'realli',
#   'cant',
#   'without',
#   'linus',
#   'love',
#   'never',
#   'thought',
#   'could',
#   'ever',
#   'love',
#   'anyon',
#   'went',
#   'fuck',
#   'relationship'],
#  ['feel', 'success', 'make', 'sens'],
#  ['im', 'feel', 'low', 'forgotten'],
#  ['feel',
#   'like',
#   'life',
#   'practic',
#   'perfect',
#   'everi',
#   'way',
#   'right',
#   'everi',
#   'happi'],
#  ['feel', 'like', 'suffer', 'produc', 'someth', 'not', 'worthwhil'],
#  ['feel', 'creativ', 'see', 'altern', 'version'],
#  ['feel', 'bit', 'nostalg', 'today'],
#  ['feel',
#   'like',
#   'show',
#   'chang',
#   'mani',
#   'countri',
#   'taken',
#   'mani',
#   'countri',
#   'way',
#   'make',
#   'decis',
#   'includ',
#   'support',
#   'increas',
#   'women',
#   'area',
#   'life'],
#  ['feel',
#   'like',
#   'dirti',
#   'trash',
#   'bin',
#   'street',
#   'nobodi',
#   'realli',
#   'sought'],
#  ['make', 'new', 'friend', 'process', 'dont', 'feel', 'slutti', 'lol'],
#  ['feel', 'bit', 'reluct', 'turn', 'peopl'],
#  ['wake', 'feel', 'absolut', 'worthless'],
#  ['feel',
#   'like',
#   'look',
#   'gorgeous',
#   'curl',
#   'instead',
#   'make',
#   'full',
#   'transit',
#   'end',
#   'get',
#   'extrem',
#   'natur',
#   'red',
#   'lowlight',
#   'bottom',
#   'section',
#   'hair'],
#  ['feel', 'gonna', 'start', 'ach', 'raini', 'season', 'come', 'next', 'year'],
#  ['glad',
#   'know',
#   'reason',
#   'recent',
#   'laps',
#   'saniti',
#   'still',
#   'feel',
#   'like',
#   'want',
#   'go',
#   'violent',
#   'rampag',
#   'slightest',
#   'inconveni'],
#  ['one',
#   'sit',
#   'stare',
#   'blank',
#   'comput',
#   'screen',
#   'scratch',
#   'head',
#   'time',
#   'drink',
#   'coupl',
#   'pot',
#   'coffe',
#   'feel',
#   'triumphant',
#   'write',
#   'first',
#   'sentenc',
#   'first',
#   'sentenc',
#   'usual',
#   'consist',
#   'poop',
#   'joke'],
#  ['feel',
#   'high',
#   'ecstat',
#   'normal',
#   'feel',
#   'like',
#   'thousand',
#   'mile',
#   'drop',
#   'unhappi',
#   'excruci'],
#  ['read', 'one', 'horrif', 'sit', 'made', 'feel', 'asham', 'world', 'live'],
#  ['could', 'feel', 'sweet', 'spirit', 'happi', 'help'],
#  ['realli',
#   'love',
#   'eat',
#   'fresh',
#   'fig',
#   'feel',
#   'delic',
#   'look',
#   'much',
#   'prettier',
#   'ugli',
#   'dri',
#   'fig'],
#  ['id', 'feel', 'better'],
#  ['watch', 'hgtv', 'feel', 'like', 'im', 'not', 'talent'],
#  ['never',
#   'feel',
#   'brave',
#   'nor',
#   'want',
#   'believ',
#   'order',
#   'brave',
#   'make',
#   'conscious',
#   'choic',
#   'whether',
#   'want',
#   'brave',
#   'not'],
#  ['feel', 'like', 'offend', 'question'],
#  ['probabl',
#   'love',
#   'hand',
#   'friend',
#   'alway',
#   'feel',
#   'bit',
#   'strang',
#   'describ',
#   'love'],
#  ['feel', 'hate', 'not', 'want', 'ignor'],
#  ['express',
#   'gene',
#   'domin',
#   'voic',
#   'feel',
#   'rather',
#   'wonder',
#   'realli',
#   'writer',
#   'poet',
#   'carefre',
#   'crazi'],
#  ['wonder', 'jealous', 'feel', 'discont', 'covetousn'],
#  ['feel',
#   'low',
#   'late',
#   'feel',
#   'hopeless',
#   'disturb',
#   'make',
#   'tire',
#   'sick',
#   'entir',
#   'live',
#   'kind',
#   'life'],
#  ['put',
#   'hand',
#   'scar',
#   'cover',
#   'chest',
#   'feel',
#   'half',
#   'heart',
#   'beat',
#   'oh',
#   'beat',
#   'feel',
#   'sweet',
#   'rhythm',
#   'remind',
#   'not',
#   'alon'],
#  ['guess', 'im', 'feel', 'littl', 'rebelli'],
#  ['feel', 'resolv', 'yet', 'somehow', 'depress'],
#  ['feel', 'tender'],
#  ['im', 'feel', 'littl', 'stress', 'alreadi'],
#  ['feel',
#   'like',
#   'accept',
#   'favourit',
#   'yet',
#   'nowher',
#   'see',
#   'terpen',
#   'respons',
#   'flavour'],
#  ['feel',
#   'bit',
#   'strang',
#   'never',
#   'felt',
#   'ever',
#   'realli',
#   'stop',
#   'write',
#   'blog'],
#  ['href', 'http', 'feel', 'groggi'],
#  ['ive',
#   'gain',
#   'wieght',
#   'realli',
#   'would',
#   'like',
#   'lose',
#   'pound',
#   'feel',
#   'like',
#   'ive',
#   'final',
#   'gotten',
#   'accept',
#   'happi',
#   'place'],
#  ['feel', 'book', 'explain', 'thing', 'well', 'easi', 'use'],
#  ['feel', 'resign', 'brought', 'docil'],
#  ['still',
#   'feel',
#   'alon',
#   'cant',
#   'give',
#   'anyth',
#   'call',
#   'feel',
#   'breath',
#   'keep',
#   'awak',
#   'feel',
#   'beat'],
#  ['feel',
#   'love',
#   'presenc',
#   'parent',
#   'daili',
#   'even',
#   'though',
#   'physic',
#   'dead',
#   'almost',
#   'two',
#   'decad'],
#  ['feel', 'pretti', 'jolli'],
#  ['read',
#   'case',
#   'son',
#   'ignor',
#   'old',
#   'helpless',
#   'parent',
#   'feel',
#   'unhappi',
#   'sad'],
#  ['feel',
#   'humili',
#   'bodi',
#   'husband',
#   'make',
#   'advanc',
#   'toward',
#   'remind',
#   'despit',
#   'ra',
#   'tri',
#   'take',
#   'life',
#   'still',
#   'find',
#   'not',
#   'sexual',
#   'attract',
#   'beauti'],
#  ['feel', 'kind', 'alon', 'helpless'],
#  ['feel', 'total', 'ignor', 'exclud'],
#  ['im', 'feel', 'serious', 'piss', 'someth', 'fantabul', 'utter', 'stupid'],
#  ['wish',
#   'could',
#   'say',
#   'hey',
#   'know',
#   'die',
#   'tomorrow',
#   'wouldnt',
#   'feel',
#   'cheat',
#   'life',
#   'regret',
#   'didnt',
#   'accomplish',
#   'someth'],
#  ['could',
#   'look',
#   'act',
#   'like',
#   'know',
#   'lie',
#   'feel',
#   'smug',
#   'know',
#   'ness',
#   'frank',
#   'way',
#   'lazi'],
#  ['go', 'home', 'feel', 'empti'],
#  ['someth',
#   'tell',
#   'girl',
#   'final',
#   'feel',
#   'brave',
#   'enough',
#   'share',
#   'news'],
#  ['feel', 'defeat', 'like', 'lion', 'prey'],
#  ['like', 'like', 'feel', 'like'],
#  ['excit', 'hope', 'person', 'us', 'wont', 'feel', 'like', 'rush'],
#  ['surround',
#   'bibl',
#   'vers',
#   'help',
#   'transcend',
#   'space',
#   'feel',
#   'safe',
#   'secur'],
#  ['know', 'feel', 'awkward', 'hesit', 'return', 'melbourn'],
#  ['feel',
#   'littl',
#   'less',
#   'gloomi',
#   'littl',
#   'optimist',
#   'littl',
#   'better',
#   'prepar',
#   'face',
#   'life',
#   'throw',
#   'way'],
#  ['wont',
#   'lie',
#   'im',
#   'littl',
#   'worri',
#   'nervous',
#   'feel',
#   'inadequ',
#   'job',
#   'ill',
#   'best',
#   'that',
#   'heaven',
#   'father',
#   'want'],
#  ['slough',
#   'carapac',
#   'crud',
#   'envelop',
#   'past',
#   'thirti',
#   'odd',
#   'hour',
#   'feel',
#   'invigor',
#   'final',
#   'readi',
#   'face',
#   'day'],
#  ['ive',
#   'busi',
#   'girl',
#   'good',
#   'type',
#   'busi',
#   'im',
#   'feel',
#   'realli',
#   'happi',
#   'thing',
#   'right',
#   'love',
#   'new',
#   'start',
#   'glasgow'],
#  ['mother', 'kept', 'leadingstr'],
#  ['set',
#   'mind',
#   'want',
#   'specif',
#   'item',
#   'need',
#   'specif',
#   'event',
#   'specif',
#   'time',
#   'find',
#   'ill',
#   'end',
#   'spend',
#   'want',
#   'feel',
#   'pressur',
#   'constraint'],
#  ['written',
#   'prayer',
#   'journal',
#   'morn',
#   'medit',
#   'great',
#   'lord',
#   'psalm',
#   'written',
#   'close',
#   'may',
#   'feel',
#   'tender',
#   'care',
#   'today'],
#  ['depress', 'actual', 'feel', 'inspir'],
#  ['feel',
#   'like',
#   'not',
#   'enough',
#   'peopl',
#   'age',
#   'actual',
#   'think',
#   'pretti',
#   'devast',
#   'come',
#   'gone'],
#  ['get', 'home', 'laze', 'around', 'pajama', 'feel', 'grouchi'],
#  ['feel', 'pretti', 'homesick', 'weekend'],
#  ['start',
#   'feel',
#   'realli',
#   'optimist',
#   'driven',
#   'paper',
#   'coz',
#   'gonna',
#   'teach',
#   'mean',
#   'way',
#   'leader'],
#  ...]

# %% [markdown]
# ## Second jeu de données

# %%
dataset_path = Path('/home/apprenant/Documents/Brief-Emotion-Analysis-Text/data/02_cleaned/cleaned_text_emotion.csv').resolve()
dataset = Dataset(dataset_path)
dataset.load()
dataset.preprocess_texts()
# Out:
# /home/apprenant/Documents/Brief-Emotion-Analysis-Text/src/utils.py:12: FutureWarning: The default value of regex will change from True to False in a future version.
#   texts = texts.str.replace(r"(http|@)\S+", "")
# /home/apprenant/Documents/Brief-Emotion-Analysis-Text/src/utils.py:16: FutureWarning: The default value of regex will change from True to False in a future version.
#   texts = texts.str.replace(r"[^a-z\':_]", " ")
# /home/apprenant/Documents/Brief-Emotion-Analysis-Text/src/utils.py:23: FutureWarning: The default value of regex will change from True to False in a future version.
#   texts = texts.str.replace(r"(can't|cannot)", 'can not')
# Time to clean up: 14.04 sec

# %%
dataset.cleaned_data.head()
# Out:
#         label                                               text
# 0       empty  know listenin bad habit earlier started freaki...
# 1     sadness               layin n bed headache ugh waitin call
# 2     sadness                     funeral ceremony gloomy friday
# 3  enthusiasm                            wants hang friends soon
# 4     neutral          want trade someone houston tickets no one

# %%
cleaned_dataset = dataset.cleaned_data

# %% [markdown]
# ### Tokenisation

# %%
cleaned_dataset_list = cleaned_dataset['text'].to_list()

tokenizer_w = WhitespaceTokenizer()
token_list2 = []
for i in cleaned_dataset_list:
    tokenized_list = tokenizer_w.tokenize(i) 
    token_list2.append(tokenized_list)

# %% [markdown]
# ### Stemming

# %%
new_list2 = stemmer_snowball(token_list2)
new_list2
# Out:
#   'sorri',
#   'next',
#   'week',
#   'sure'],
#  ['nd', 'last', 'episod', 'jay', 'leno', 'itll', 'never', 'nite', 'twitter'],
#  ['not', 'feel', 'good'],
#  ['ok',
#   'time',
#   'nodd',
#   'gonna',
#   'long',
#   'day',
#   'tomorrow',
#   'say',
#   'goodby',
#   'car',
#   'good'],
#  ['fakin', 'kisha', 'luck'],
#  ['take',
#   'nap',
#   'work',
#   'no',
#   'sleep',
#   'right',
#   'nap',
#   'felt',
#   'good',
#   'seem',
#   'like',
#   'bad',
#   'idea'],
#  ['go', 'home', "i'v", 'serious', 'enough'],
#  ['count', 'minut', 'dad', 'g', 'friend', 'leav'],
#  ['miss', 'oklahoma', 'listen', 'citizen', 'cope', 'til', 'pass'],
#  ['tens', 'emot', 'not'],
#  ['fun', 'miss', 'guy', 'lot'],
#  ['make', 'sad'],
#  ['play',
#   'game',
#   'watch',
#   'straight',
#   'peopl',
#   'hook',
#   'not',
#   'leav',
#   'anoth',
#   'reason'],
#  ['yeah', 'work', 'today', 'never', 'mind', 'one', 'day', 'sun', 'sun', 'sun'],
#  ['feel', 'like', 'im', 'go', 'cough', 'lung'],
#  ['funni', "i'm", 'kinda', 'sad', 'last', 'day'],
#  ['not', 'think', 'either', 'not', 'rememb'],
#  ['anyon',
#   'got',
#   'jbs',
#   'live',
#   'chat',
#   'vid',
#   'school',
#   'saw',
#   'joe',
#   'hug',
#   'tackl',
#   'nick',
#   'lol'],
#  ['jenni', 'fell', 'asleep', 'not', 'come'],
#  ['love', 'not'],
#  ['wish', 'teas', 'movi', 'night'],
#  ['lost', 'follow', 'night', 'nobodi', 'like'],
#  ["i'v",
#   'miss',
#   'one',
#   'year',
#   'forbidden',
#   'fruit',
#   'tree',
#   'garden',
#   'munch',
#   'disappoint',
#   'one'],
#  ['want', 'new', 'phone', "i'v", 'seen', 'much', 'cellphon', 'commerci'],
#  ["i'm", 'soo', 'sad', 'edg', 'page', 'not', 'gonna', 'come', 'cri'],
#  ['time',
#   'realli',
#   'need',
#   'shut',
#   "i'm",
#   'go',
#   'sleep',
#   'head',
#   'ach',
#   'bad',
#   'realli',
#   'not',
#   'take'],
#  ['love', 'knw', 'gna', 'cut', 'stuff', 'tv'],
#  ['becuz', 'braggin'],
#  ['im',
#   'strict',
#   'diet',
#   'ugh',
#   'feel',
#   'like',
#   'cheat',
#   'one',
#   'day',
#   'ill',
#   'throw',
#   'everyth'],
#  ['oh', 'no', 'hub', 'sick', 'hope', 'not', 'catch'],
#  ['ze',
#   'franz',
#   'not',
#   'friend',
#   'think',
#   'think',
#   "i'm",
#   'creepi',
#   'stalker',
#   'sommat',
#   'hmph'],
#  ['take',
#   'back',
#   'horribl',
#   'shoe',
#   'mum',
#   'made',
#   'get',
#   'urgh',
#   'nasti',
#   'footwear',
#   'problem',
#   'not',
#   'find',
#   'shoe'],
#  ['ran', 'money', 'r', 'sad', 'panda'],
#  ['find', 'today', 'first', 'kiss'],
#  ['cal',
#   'dachshund',
#   'rescu',
#   'found',
#   'home',
#   'foster',
#   'pup',
#   'max',
#   "i'm",
#   'sad',
#   'see',
#   'leav'],
#  ['wow',
#   'feel',
#   'like',
#   'ish',
#   'realli',
#   'feel',
#   'bad',
#   'ignor',
#   'ahol',
#   'wont',
#   'overturn',
#   'prop'],
#  ['work', 'finish', 'pm', 'bo'],
#  ['wish', 'not', 'teas', 'movi', 'night'],
#  ['gotta', 'wiat', 'till', 'next', 'week', 'btw', 'mumbai'],
#  ['dont', 'know', 'tire', 'today', 'bye', 'time', 'beddi'],
#  ['intentando', 'intentarlo'],
#  ['mayb',
#   'take',
#   'drink',
#   'feel',
#   'massiv',
#   'hangov',
#   'still',
#   'not',
#   'yself',
#   'today'],
#  ['realli',
#   'bad',
#   'head',
#   'ach',
#   'gonna',
#   'go',
#   'bed',
#   'might',
#   'back',
#   'mayb',
#   'not',
#   'bye',
#   'bye'],
#  ['friend',
#   'travel',
#   'tale',
#   'held',
#   'farewel',
#   'parti',
#   'kinda',
#   'disappoint',
#   'would',
#   'still',
#   'sep',
#   'fault'],
#  ['night',
#   'not',
#   'talk',
#   'victor',
#   "i'm",
#   'bore',
#   'night',
#   'gr',
#   'hate',
#   'shit'],
#  ['go', 'die', 'tomorrow', 'night'],
#  ['ooh', 'maggi', 'goreng', 'yum', 'cant', 'eat', 'sore', 'throat', 'cmin'],
#  ['gonna',
#   'get',
#   'tri',
#   'catch',
#   'z',
#   'no',
#   'high',
#   'school',
#   'tomorrow',
#   'realli',
#   'suck',
#   'wish',
#   'not',
#   'grow'],
#  ['morn', 'hon', 'breakfast', 'cant', 'decid'],
#  ['sleep', 'lost', 'voic', 'coupl', 'day', 'ago'],
#  ['mention',
#   'bf',
#   'bubbl',
#   'wsop',
#   'employe',
#   'event',
#   'hrs',
#   'aa',
#   'work',
#   'doubl',
#   'next',
#   'week'],
#  ['sleepi', 'earlier', 'didnt', 'get', 'see', 'matt'],
#  ['big',
#   'day',
#   'day',
#   'xt',
#   'launch',
#   'amaz',
#   'much',
#   'free',
#   'stuff',
#   'thanx',
#   'edg',
#   'telecom',
#   'found',
#   'phone',
#   'want',
#   'cnt',
#   'afford',
#   'yet',
#   'tho'],
#  ['oh',
#   'yeah',
#   "i'm",
#   'poorest',
#   'person',
#   'shouldnt',
#   'joke',
#   'poor',
#   'peopl'],
#  ['realiz', 'spell', 'quot', 'ador', 'quot', 'wrong', 'tweet', 'must', 'hate'],
#  ['gone'],
#  ['oh', 'well', 'hope', 'get', 'better'],
#  ['crew',
#   'pleas',
#   'dont',
#   'dont',
#   'think',
#   'could',
#   'wrong',
#   'number',
#   'time'],
#  ['glow', 'face', 'complexion', 'alway', 'pale'],
#  ['downloadfestiv',
#   'lineup',
#   'not',
#   'good',
#   'thought',
#   'awesom',
#   'band',
#   'festiv',
#   'miss',
#   'dl'],
#  ['not',
#   'watch',
#   'gossip',
#   'girl',
#   'age',
#   'need',
#   'one',
#   'tree',
#   'hill',
#   'season',
#   'god',
#   "i'm",
#   'slow'],
#  ['cycl',
#   'tho',
#   'that',
#   'good',
#   'healthi',
#   'eat',
#   'healthi',
#   'eat',
#   'contradict',
#   'term'],
#  ["i'm", 'kinda', 'sick', 'n', 'tire', 'bs', 'guy', 'dish'],
#  ['hate',
#   'fleetwood',
#   'favorit',
#   'band',
#   "i'm",
#   'jealous',
#   'ok',
#   'still',
#   'love',
#   'haha'],
#  ['wish', 'carlton', 'game', 'live', 'stupid', 'channel', 'lol'],
#  ['earli',
#   'tomorrow',
#   'head',
#   'bed',
#   'keep',
#   'say',
#   "i'm",
#   'go',
#   'take',
#   'midday',
#   'nap',
#   'not',
#   'happen',
#   'week',
#   'yet'],
#  ['up', 'ketauan', 'cabut', 'sama', 'nih'],
#  ['say', 'morn', 'everyon', 'work', 'min'],
#  ['no',
#   'no',
#   'bt',
#   'gamer',
#   'like',
#   'year',
#   'made',
#   'attempt',
#   'lol',
#   'yea',
#   'luvd',
#   'f',
#   'extent'],
#  ['pm', 'friday', 'left', 'thursday', 'sure'],
#  ["i'm", 'sorri', 'ya', 'gotta', 'let', 'know', "i'v", 'book', 'week'],
#  ['hahaha',
#   'oh',
#   'man',
#   'pleas',
#   'come',
#   'pomona',
#   'would',
#   'love',
#   'see',
#   'everyday',
#   'instead',
#   'like',
#   'year'],
#  ['miss', 'come', 'michigan', 'like', 'not', 'wait', 'till', 'juli'],
#  ['mayb', 'good', 'night', 'sleep', 'everyon'],
#  ['far', 'pdhpe', 'assign', 'due', 'next', 'week', 'english', 'homework'],
#  ['forgot', 'access', 'card', 'car', 'lazi', 'fetch'],
#  ['yea', 'tough', 'keep', 'go', 'sometim', "i'm", 'not', 'sure', 'worth'],
#  ['dissapoint', 'hhaha'],
#  ['hun',
#   'okay',
#   'see',
#   'alot',
#   'post',
#   'exercis',
#   'like',
#   'mad',
#   'not',
#   'eat',
#   'sleep'],
#  ['oh', 'no', 'tweetdeck', 'malfunct', ':o', 'il', 'web', 'fixd'],
#  ["i'm",
#   'sorri',
#   'still',
#   'sick',
#   'u',
#   'know',
#   'know',
#   'u',
#   'guess',
#   'quot',
#   'pelzer',
#   'present',
#   'quot'],
#  ['adam',
#   'samberg',
#   'new',
#   'moon',
#   'trailor',
#   'good',
#   'even',
#   'bad',
#   'cabl',
#   'friday'],
#  ['happen', "i'm", 'afraid', 'miss', 'larg', 'part', 'stori'],
#  ['work', ':'],
#  ['hell', 'yes', "i'm", 'late'],
#  ['dell',
#   'fx',
#   'pc',
#   'ip',
#   'audio',
#   'devic',
#   'teradici',
#   'give',
#   'hard',
#   'time',
#   'linux',
#   'ubuntu',
#   'jaunti',
#   'kernel',
#   'isnt',
#   'load',
#   'snd',
#   'hda',
#   'intel',
#   'drv'],
#  ['got', 'ass', 'kick', 'tripoli', 'lol', 'got', 'bad', 'card', 'suck'],
#  ['creep',
#   'ice',
#   'cream',
#   'social',
#   'good',
#   'time',
#   'lar',
#   'real',
#   'girl',
#   'sad',
#   'movi'],
#  ['hot', 'huf'],
#  ['close', 'distanc', 'close', 'everyth', 'seem', 'distant'],
#  ['anoth', 'one', 'bite', 'dust'],
#  ['ah', 'quot', 'let', 'right', 'one', 'quot', 'dvd', 'broke'],
#  ['hey',
#   'love',
#   'ac',
#   'see',
#   'onlin',
#   'not',
#   'yet',
#   'cant',
#   'wait',
#   'buy',
#   'look',
#   'amaz'],
#  ['thought', 'dwell', 'certain', 'person'],
#  ['fml', 'work', 'uniform', 'wash', 'line'],
#  ['ohh', 'shit', 'realiz', 'still', 'not', 'talk', 'b', 'like', 'dat', 'time'],
#  ['nd',
#   'written',
#   'fuck',
#   'get',
#   'less',
#   'idea',
#   'everi',
#   'day',
#   'everi',
#   'day'],
#  ['naw', 'doesnt', 'match', 'lol', 'no', 'shenanigan', 'discuss', 'thing'],
#  ['not', 'part', 'unfortun'],
#  ['dude',
#   'not',
#   'know',
#   'person',
#   'experi',
#   'sorri',
#   'someth',
#   'like',
#   'went'],
#  ['aww', 'well', 'random', 'woke', 'not', 'sleep', 'mani', 'thing', 'mind'],
#  ['babi', 'miss'],
#  ['sinc', 'obvious', 'live', 'alaska', 'radio', 'station', 'get'],
#  ['murder', 'two', 'fuck', 'mous', 'cant', 'sleep'],
#  ['oh', 'noe', 'hey', 'what', 'tatoo', 'say'],
#  ['not', 'vcr'],
#  ['wish', 'could', 'time', 'xbox', 'project', 'tie'],
#  ['pancak', 'alway', 'end', 'soggi'],
#  ['big',
#   'zongzi',
#   'lunch',
#   'ate',
#   'not',
#   'work',
#   'work',
#   'less',
#   'eat',
#   'w',
#   'h',
#   'useless',
#   'becom'],
#  ['sososo', 'bum', 'like', 'realli', 'bum', 'hate', 'rain', 'ruin', 'date'],
#  ['work',
#   'late',
#   'night',
#   'dell',
#   'notebook',
#   'dell',
#   'qualiti',
#   'gone',
#   'hill',
#   'warrenti',
#   'servic',
#   'suck',
#   'poor',
#   'peopl',
#   'buy',
#   'mac',
#   'instead'],
#  ['wow', 'hurt', 'way', 'wors', 'thought', 'would'],
#  ['none', 'thought', 'make', 'sens', "i'm", 'sober'],
#  ['know', 'right', 'hope', 'someth', 'come', 'though'],
#  ['cant', 'sleep', 'tomorrow', 'must', 'wake', 'earli'],
#  ['bodi',
#   'alreadi',
#   'develop',
#   'mind',
#   'mind',
#   'refus',
#   'co',
#   'oper',
#   'set',
#   'schedul'],
#  ['suppos',
#   'back',
#   'sun',
#   'via',
#   'privat',
#   'jet',
#   'btw',
#   ':o',
#   'mite',
#   'hav',
#   'stay',
#   'bymyself',
#   'thnk',
#   'god',
#   'anoth',
#   'week',
#   'amp',
#   'want',
#   'bruno'],
#  ['trash', 'repop', 'get', 'tomorrow', 'night', 'suppos'],
#  ['nurs',
#   'bruis',
#   'motorbik',
#   'crash',
#   'wednesday',
#   'night',
#   'leav',
#   'london',
#   'workplac',
#   'ground',
#   'much',
#   'harder',
#   'older',
#   'get'],
#  ['bore', 'headach'],
#  ['huge', 'headach', 'goodnight'],
#  ['feel',
#   'like',
#   'crap',
#   'whenev',
#   'lay',
#   'hate',
#   'heartburn',
#   'amp',
#   'backach'],
#  ['miss', 'lone', 'empti', 'without'],
#  ['noic',
#   'realis',
#   'exam',
#   'week',
#   'forgot',
#   'whole',
#   'week',
#   'unit',
#   'term',
#   'thing',
#   ':'],
#  ['justwatch',
#   'like',
#   'straight',
#   'episod',
#   'escap',
#   'id',
#   'discoveri',
#   'channel',
#   'guy',
#   'imprison',
#   'women',
#   'kill',
#   'cook'],
#  ['miss', 'everyon'],
#  ['gone', 'bed', 'age', 'ago', 'damn', 'tedtalk', 'gotta', 'get', 'earli'],
#  ['give', 'point'],
#  ['make',
#   'pork',
#   'product',
#   "they'v",
#   'fuck',
#   'stop',
#   'import',
#   'dubai',
#   'bad',
#   'time'],
#  ['anoth',
#   'build',
#   'fail',
#   'someth',
#   'not',
#   'right',
#   'big',
#   'scheme',
#   'thing'],
#  ['wife', 'took', 'last', 'no', 'mcdonald', 'breakfast', 'today'],
#  ['wish', 'go', 'love', 'sound'],
#  ['sisser',
#   'move',
#   'tomorrow',
#   'make',
#   'sad',
#   'actual',
#   'guess',
#   'technic',
#   'coupl',
#   'hour',
#   'sinc',
#   'alreadi',
#   'friday'],
#  ['keep', 'fall', 'asleep', "i'm", 'suppos', 'awak', 'miss', 'babyy'],
#  ['not'],
#  ['way', 'nottingham', 'not', 'want', 'go'],
#  ['no', 'churchil', 'down', 'tomorrow'],
#  ['chicago', 'not', 'ride', 'call', 'back'],
#  ['k',
#   'goodnight',
#   'gotta',
#   'chuck',
#   'e',
#   'chees',
#   'tomorrow',
#   'follow',
#   'kindergarten',
#   'shot',
#   'physic',
#   'bla'],
#  ['need',
#   'wake',
#   'earlier',
#   "i'm",
#   'actual',
#   'tire',
#   'enough',
#   'fall',
#   'asleep'],
#  ['bahh', 'polic', 'end', 'parti', 'start'],
#  ["i'v", 'got', 'catch', 'bus', 'work'],
#  ['sad'],
#  ['omg', 'never', 'seen', 'the', 'ring', 'creppi', 'ass', 'movi'],
#  ['man', 'got', 'iphon', 'im', 'jealous'],
#  ['funni', 'u', 'havent', 'show', 'love', 'yet'],
#  ['absolut', 'nothin'],
#  ['luv',
#   'ur',
#   'admit',
#   'niley',
#   'kiss',
#   ':',
#   'chang',
#   'mind',
#   'haha',
#   'amp',
#   'demi',
#   'sterl',
#   ':',
#   'not',
#   'jemi',
#   'still',
#   'cute'],
#  ['make',
#   'feel',
#   'better',
#   'lost',
#   'overnight',
#   'caus',
#   'post',
#   'pictur',
#   'babi'],
#  ['still', 'sick', 'sigh'],
#  ['oh', 'poor', 'beth', 'friend', "i'm", 'not', 'naughti', "i'm", 'unperfect'],
#  ['josh', 'call', 'big', 'bucket', 'ugli', 'wish', 'luck', 'audit', 'tweet'],
#  ['feel', 'realli', 'weird'],
#  ["i'm", 'tri', 'self', 'learn', 'photoshop', 'not', 'go', 'well'],
#  ['ever',
#   'seen',
#   'tv',
#   'show',
#   'dead',
#   'like',
#   'die',
#   'becam',
#   'grim',
#   'reaper',
#   'take',
#   'peopl',
#   'soul',
#   'accid'],
#  ["i'm", 'sorri', "i'm", 'think', 'hope', 'week', 'get', 'better'],
#  ['steam',
#   'punlk',
#   'fashion',
#   'show',
#   'anim',
#   'north',
#   'first',
#   'year',
#   'sinc',
#   'torcon',
#   'not',
#   'back',
#   'til',
#   'amp',
#   'miss'],
#  ['throat', 'hurt', 'gonna', 'go', 'read', 'go', 'bed', 'text', 'mee'],
#  ['die', 'hangout', 'friday', 'afternoon'],
#  ['eh', 'cold'],
#  ['man', 'got', 'iphon', 'im', 'jealous'],
#  ['fjdskal', 'im', 'realli', 'frustrat'],
#  ['aww', 'youtub'],
#  ['wonder', 'come', 'mcdonald', 'take', 'long', 'deliv', 'food'],
#  ['ya',
#   'weather',
#   'super',
#   'weird',
#   'look',
#   'like',
#   'gonna',
#   'rain',
#   'today',
#   'cours',
#   'not',
#   'darnitt'],
#  ['much',
#   'injustic',
#   'imagin',
#   'get',
#   'wors',
#   'get',
#   'better',
#   'afraid',
#   'no',
#   'doubt',
#   'sorri'],
#  ['miss', 'nostalgia', 'everyon', 'pleas', 'kick', 'tushar'],
#  ["i'm", 'kind', 'sick', 'n', 'tire', 'bs', 'guy', 'dish'],
#  ['class',
#   'color',
#   'day',
#   'tomorrow',
#   'last',
#   'time',
#   'lot',
#   'rememb',
#   'tomorrow',
#   'bet',
#   "i'll",
#   'forget',
#   '_'],
#  ['idk',
#   'lol',
#   'head',
#   'hurt',
#   'rli',
#   'bad',
#   'amp',
#   'stomach',
#   'hmm',
#   'person',
#   'think',
#   'ive',
#   'deal',
#   'wit'],
#  ['expens'],
#  ['wtf',
#   'facebook',
#   'clear',
#   'whole',
#   'survey',
#   'last',
#   'q',
#   'night',
#   'get',
#   'better',
#   'better',
#   'els',
#   'next'],
#  ['say', 'good', 'say', 'bad', 'afternoon'],
#  ['say', "i'v", 'got', 'number', 'get', 'low'],
#  ['miss', 'twitast', 'fwiend'],
#  ['take', 'advic', 'lookin', 'phone', 'cost', 'relationship'],
#  ['play', 'street', 'fighter', 'iv', 'seth', 'rape'],
#  ['weird', 'guy', 'hous', 'without', 'not', 'like'],
#  ['fuck',
#   'wast',
#   'deodor',
#   'aint',
#   'goin',
#   'no',
#   'aint',
#   'havin',
#   'compani',
#   'let',
#   'funk',
#   'ya'],
#  ['wish', 'knew', 'curs', 'tumblr'],
#  ['beauti', 'day', 'shame', "i'v", 'got', 'spend', 'offic'],
#  ['came',
#   'q:',
#   'quot',
#   'recommend',
#   'hairdress',
#   'u',
#   'r',
#   'full',
#   'suggest',
#   'other',
#   'quot',
#   'ego',
#   'talk',
#   "i'm",
#   'line'],
#  ['busi', 'exam', 'tomorrow'],
#  ['oh', 'know', 'budget'],
#  ['finish',
#   'watch',
#   'seri',
#   'return',
#   'chaser',
#   'war',
#   'everyth',
#   'realli',
#   'quit',
#   'crap',
#   'compar',
#   'use'],
#  ['wow',
#   'realiz',
#   'not',
#   'check',
#   'twitter',
#   'sinc',
#   'saw',
#   'list',
#   'good',
#   'news',
#   'got',
#   'lot',
#   'done',
#   'bad',
#   'news',
#   'not',
#   'know',
#   'day',
#   'went'],
#  ['miss', 'bestfriend', ":'", 'left', 'school'],
#  ['ouch', 'earphon', 'shock'],
#  ["i'm", 'tri', 'sleep', 'not', 'work'],
#  ['tummi', 'hurt'],
#  ['back', 'grimsbi', 'suck', 'bein', 'back', 'amazin', 'wknd', 'anyway'],
#  ['farewel', 'employe', 'tonight'],
#  ['haha',
#   ':',
#   'ive',
#   'got',
#   'no',
#   'one',
#   'go',
#   'curs',
#   'none',
#   'friend',
#   'like',
#   'tai',
#   'lol'],
#  ['gorgeous', 'weather', 'no', 'bike'],
#  ['morn', 'water', 'heat', 'pack', 'not', 'bath', 'realli', 'want', 'bath'],
#  ['girl', 'confus'],
#  ['lyrically_m', 'would'],
#  ['see', 'u', 'not', 'comin', 'citi', 'u', 'comin'],
#  ['blackout', 'citi', 'never', 'good'],
#  ['aww', 'mayb', 'traumat'],
#  ['flight',
#   'alreadi',
#   'book',
#   'plus',
#   'ggd',
#   'st',
#   'birthday',
#   'not',
#   'miss',
#   'especi',
#   'miss',
#   'ggd'],
#  ['live',
#   'small',
#   'market',
#   'deliv',
#   'day',
#   'old',
#   'bread',
#   'food',
#   'bank',
#   'time',
#   'realli',
#   'tough',
#   'even'],
#  ['drunk',
#   'hickup',
#   'pretti',
#   'laid',
#   'back',
#   'great',
#   'night',
#   'still',
#   'not',
#   'help',
#   'mad',
#   'situat',
#   'put'],
#  ['think',
#   'take',
#   'medicin',
#   'cuz',
#   'laugh',
#   'hard',
#   'head',
#   'not',
#   'much',
#   'pain',
#   'thought',
#   'laughter',
#   'gud'],
#  ['ugh', 'much', 'happen', 'today', 'realli', 'need', 'hug'],
#  ['bore', 'wanna', 'go', 'taekwando'],
#  ['watch', 'leno', 'second', 'last', 'time', 'tonight', 'show'],
#  ['ur', 'pic', 'gone'],
#  ['tongu', 'still', 'hurt', 'need', 'sleep'],
#  ['twitter'],
#  ['chris',
#   'stay',
#   'glasgow',
#   'instead',
#   'caus',
#   'absolut',
#   'no',
#   'accomod',
#   'edinburgh',
#   'due',
#   'marathon'],
#  ['not',
#   'wait',
#   'till',
#   'sunday',
#   'new',
#   'episod',
#   'supernatur',
#   'episod',
#   'left'],
#  ['aw', 'ok', 'lol', 'hope', 'im', 'still', 'not', 'back', 'state'],
#  ['sad', 'tweet', 'sad'],
#  ['need', 'littl', 'lie', 'not', 'feel', 'great', 'today', 'boo'],
#  ['not',
#   'workplac',
#   'short',
#   'sleev',
#   'shirt',
#   'absolut',
#   'necessari',
#   'today'],
#  ['decid', 'not', 'stand', 'alltop', 'spam', 'longer'],
#  ['anal', 'sex', 'forgot', 'lube', 'damn', 'may', 'need', 'go', 'e', 'r'],
#  ['playn', 'madden', 'austin', 'im', 'go', 'miss'],
#  ['miss', 'rich'],
#  ['headach', 'centuri', 'come', 'feel', 'fuck'],
#  ['disappoint',
#   'know',
#   'got',
#   'silver',
#   'award',
#   'want',
#   'gold',
#   'award',
#   'hate',
#   'second',
#   'best'],
#  ['pleas', 'make', 'livechat', 'saturday', 'cus', 'go', 'school', 'weekday'],
#  ['want',
#   'go',
#   'back',
#   'bed',
#   'child',
#   'look',
#   'may',
#   'sleep',
#   'sunday',
#   'enevit',
#   'hangov',
#   'may',
#   'requir'],
#  ['got', 'mad', 'tire', 'no', 'sex', 'sleepytim', 'night'],
#  ['twitter', 'shit', 'bore', 'c', 'not', 'month'],
#  ['anyon',
#   'know',
#   'convert',
#   'est',
#   'aus',
#   'time',
#   'rofl',
#   'xd',
#   'fuck',
#   'radio',
#   'disney'],
#  ['home',
#   'ice',
#   'cream',
#   'tweet',
#   'first',
#   'tweet',
#   'no',
#   'pic',
#   'camera',
#   'batteri',
#   'die',
#   'last',
#   'night',
#   'forgot',
#   'charg'],
#  ['ok',
#   'that',
#   'subt',
#   'say',
#   "i'm",
#   'no',
#   'longer',
#   'fave',
#   'temm',
#   'thing',
#   'firang',
#   'steal',
#   'vocab',
#   'ur',
#   'eat',
#   'word'],
#  ['bye', 'scotti', "i'm", 'gonna', 'miss', 'ili', 'lt'],
#  ['new', 'comment', 'jowki:', 'wish', 'time', 'blog', 'often'],
#  ['get', 'temporari', 'tattoo', 'would', 'total', 'sad', 'die'],
#  ['gray', 'feel', 'neglect'],
#  ['oh',
#   'know',
#   'feel',
#   'damn',
#   'repres',
#   'bank',
#   'america',
#   'tri',
#   'make',
#   'sound',
#   'like',
#   'b'],
#  ['tire', 'cold', 'runni'],
#  ['dun',
#   'wanna',
#   'travel',
#   'way',
#   'lunch',
#   'yeah',
#   'nice',
#   'place',
#   'miss',
#   'e',
#   'punjab',
#   'though'],
#  ['mass',
#   'cleanout',
#   'room',
#   'rearrang',
#   'sent',
#   'mother',
#   'buy',
#   'bin',
#   'bookshelf',
#   'sinc',
#   'mine',
#   'suck',
#   'bad',
#   'mood'],
#  ['rob', 'got', 'lucki', 'game', 'beat'],
#  ['feel',
#   'realli',
#   'sick',
#   'watch',
#   'fifth',
#   'element',
#   'smoke',
#   'cigg',
#   'ugh',
#   'hate',
#   'cold'],
#  ['bah', 'not', 'think', 'fb', 'fan', 'page', 'get'],
#  ['someon', 'save', 'dont', 'want', 'pack', 'anymor'],
#  ['home', 'school', 'shitest', 'day', 'today'],
#  ['sweeti',
#   'sat',
#   'tabl',
#   'morn',
#   'woke',
#   'sweet',
#   'oh',
#   'btw',
#   'think',
#   "i'll",
#   'home',
#   'around',
#   'pm',
#   'x'],
#  ['bruis', 'knee', 'make', 'hard', 'skate', 'tomorrow'],
#  ['lol',
#   'went',
#   'buy',
#   'new',
#   'laptop',
#   'feb',
#   'alreadi',
#   'knew',
#   'lol',
#   'look',
#   'anyway',
#   'walk',
#   'away',
#   'sadfac',
#   ':'],
#  ['fyi',
#   'no',
#   'internet',
#   'thurstag',
#   'saturday',
#   'feel',
#   'becom',
#   'x',
#   'product',
#   'day'],
#  ['sit', 'everyon', 'took', 'good', 'seat'],
#  ['no', 'free', 'wifi', 'vacay', 'ruin'],
#  ['ah', 'well', 'least', "i'm"],
#  ['maatt',
#   'havent',
#   'spoken',
#   'age',
#   'dude',
#   'dont',
#   'forget',
#   'bout',
#   'ur',
#   'aussi',
#   'fan',
#   'lool',
#   'love',
#   'ya',
#   'xx'],
#  ['oh', 'wait', 'wrong', 'state'],
#  ['fuck', 'cold', 'north', 'like', 'df', 'yesterday'],
#  ['u',
#   'miss',
#   'ur',
#   'frnds',
#   'hear',
#   'quot',
#   'manasellaam',
#   'quot',
#   'kulir',
#   'degre',
#   'movi',
#   'amaz',
#   'nanbargal',
#   'miss',
#   'u',
#   'guy'],
#  ['tri',
#   'sleep',
#   'without',
#   'pill',
#   'not',
#   'work',
#   'wide',
#   'awak',
#   'late',
#   'take',
#   "i'll",
#   'sleep',
#   'til',
#   'pm'],
#  ['phone', 'die', 'soon', 'oh', 'no'],
#  ['sorri', 'mean'],
#  ['forgot', 'power', 'cabl', 'home', 'today'],
#  ['dog',
#   'eye',
#   'seem',
#   'bad',
#   'fork',
#   'new',
#   'wash',
#   'machin',
#   'not',
#   'vet',
#   'bill',
#   'top',
#   'eh'],
#  ['not',
#   'sleep',
#   'not',
#   'find',
#   'grandmoth',
#   'quilt',
#   'locket',
#   "i'm",
#   'sick',
#   'caus',
#   'may',
#   'lost',
#   'somehow',
#   'stolen'],
#  ['thought', 'go', 'see', 'pic', 'clean', 'car'],
#  ['want', 'im', 'not', 'amp', 'c', 'say', "'s", 'wanna', 'make', 'except'],
#  ['no',
#   'amaz',
#   'thing',
#   'keep',
#   'onlin',
#   'convers',
#   'one',
#   'place',
#   'unfortun',
#   'place',
#   'googl'],
#  ['sorri', 'spanish', 'moment'],
#  ['yay', 'that', 'sp', 'far', 'away'],
#  ['must', 'clear', 'dvr', 'get', 'rid', 'tomorrw'],
#  ['bum', 'f', 'f', 'f', 'broke'],
#  ['sign',
#   'account',
#   'polit',
#   'websit',
#   'could',
#   'post',
#   'comment',
#   'not',
#   'work'],
#  ['come', 'never', 'sleep', 'past', 'not', 'good'],
#  ...]
